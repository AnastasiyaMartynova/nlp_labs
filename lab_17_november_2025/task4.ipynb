# %%
pip install "transformers>=4.40.1"
# Out:
# Collecting transformers>=4.40.1
#   Using cached transformers-4.57.1-py3-none-any.whl.metadata (43 kB)
# Collecting accelerate>=0.27.2
#   Downloading accelerate-1.12.0-py3-none-any.whl.metadata (19 kB)
# Collecting torch
#   Downloading torch-2.9.1-cp311-cp311-win_amd64.whl.metadata (30 kB)
# Collecting filelock (from transformers>=4.40.1)
#   Using cached filelock-3.20.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting huggingface-hub<1.0,>=0.34.0 (from transformers>=4.40.1)
#   Using cached huggingface_hub-0.36.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from transformers>=4.40.1) (2.3.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from transformers>=4.40.1) (25.0)
# Collecting pyyaml>=5.1 (from transformers>=4.40.1)
#   Using cached pyyaml-6.0.3-cp311-cp311-win_amd64.whl.metadata (2.4 kB)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from transformers>=4.40.1) (2025.11.3)
# Requirement already satisfied: requests in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from transformers>=4.40.1) (2.32.5)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers>=4.40.1)
#   Using cached tokenizers-0.22.1-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Collecting safetensors>=0.4.3 (from transformers>=4.40.1)
#   Downloading safetensors-0.7.0-cp38-abi3-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: tqdm>=4.27 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from transformers>=4.40.1) (4.67.1)
# Requirement already satisfied: psutil in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from accelerate>=0.27.2) (7.1.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from torch) (4.15.0)
# Collecting sympy>=1.13.3 (from torch)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from torch) (3.5)
# Collecting jinja2 (from torch)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec>=0.8.5 (from torch)
#   Using cached fsspec-2025.10.0-py3-none-any.whl.metadata (10 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: colorama in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from tqdm>=4.27->transformers>=4.40.1) (0.4.6)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Using cached markupsafe-3.0.3-cp311-cp311-win_amd64.whl.metadata (2.8 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from requests->transformers>=4.40.1) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from requests->transformers>=4.40.1) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from requests->transformers>=4.40.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from requests->transformers>=4.40.1) (2025.10.5)
# Using cached transformers-4.57.1-py3-none-any.whl (12.0 MB)
# Downloading accelerate-1.12.0-py3-none-any.whl (380 kB)
#    ---------------------------------------- 0.0/380.9 kB ? eta -:--:--
#    -------- ------------------------------- 81.9/380.9 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 380.9/380.9 kB 3.4 MB/s eta 0:00:00
# Downloading torch-2.9.1-cp311-cp311-win_amd64.whl (111.0 MB)
#    ---------------------------------------- 0.0/111.0 MB ? eta -:--:--
#    ---------------------------------------- 0.7/111.0 MB 14.8 MB/s eta 0:00:08
#     --------------------------------------- 1.5/111.0 MB 15.8 MB/s eta 0:00:07
#     --------------------------------------- 2.6/111.0 MB 18.2 MB/s eta 0:00:06
#    - -------------------------------------- 3.5/111.0 MB 20.2 MB/s eta 0:00:06
#    - -------------------------------------- 3.5/111.0 MB 20.2 MB/s eta 0:00:06
#    -- ------------------------------------- 5.6/111.0 MB 21.0 MB/s eta 0:00:06
#    -- ------------------------------------- 6.1/111.0 MB 19.4 MB/s eta 0:00:06
#    -- ------------------------------------- 7.4/111.0 MB 21.5 MB/s eta 0:00:05
#    --- ------------------------------------ 8.6/111.0 MB 22.1 MB/s eta 0:00:05
#    --- ------------------------------------ 9.9/111.0 MB 22.5 MB/s eta 0:00:05
#    --- ------------------------------------ 11.1/111.0 MB 23.4 MB/s eta 0:00:05
#    ---- ----------------------------------- 12.1/111.0 MB 24.2 MB/s eta 0:00:05
#    ---- ----------------------------------- 13.3/111.0 MB 24.2 MB/s eta 0:00:05
#    ----- ---------------------------------- 14.5/111.0 MB 28.5 MB/s eta 0:00:04
#    ----- ---------------------------------- 15.6/111.0 MB 25.2 MB/s eta 0:00:04
#    ------ --------------------------------- 16.7/111.0 MB 25.2 MB/s eta 0:00:04
#    ------ --------------------------------- 18.0/111.0 MB 25.2 MB/s eta 0:00:04
#    ------ --------------------------------- 19.3/111.0 MB 26.2 MB/s eta 0:00:04
#    ------- -------------------------------- 20.5/111.0 MB 26.2 MB/s eta 0:00:04
#    ------- -------------------------------- 21.5/111.0 MB 25.1 MB/s eta 0:00:04
#    -------- ------------------------------- 22.7/111.0 MB 25.2 MB/s eta 0:00:04
#    -------- ------------------------------- 23.8/111.0 MB 25.2 MB/s eta 0:00:04
#    --------- ------------------------------ 25.1/111.0 MB 26.2 MB/s eta 0:00:04
#    --------- ------------------------------ 26.1/111.0 MB 25.1 MB/s eta 0:00:04
#    --------- ------------------------------ 27.3/111.0 MB 25.2 MB/s eta 0:00:04
#    ---------- ----------------------------- 28.5/111.0 MB 25.2 MB/s eta 0:00:04
#    ---------- ----------------------------- 29.5/111.0 MB 26.2 MB/s eta 0:00:04
#    ----------- ---------------------------- 30.7/111.0 MB 25.2 MB/s eta 0:00:04
#    ----------- ---------------------------- 32.0/111.0 MB 26.2 MB/s eta 0:00:04
#    ----------- ----------------------------
1 MB/s eta 0:00:02
#    ----------------------------- ---------- 82.3/111.0 MB 21.9 MB/s eta 0:00:02
#    ------------------------------ --------- 83.3/111.0 MB 21.1 MB/s eta 0:00:02
#    ------------------------------ --------- 83.7/111.0 MB 21.9 MB/s eta 0:00:02
#    ------------------------------ --------- 85.3/111.0 MB 21.8 MB/s eta 0:00:02
#    ------------------------------- -------- 86.3/111.0 MB 21.8 MB/s eta 0:00:02
#    ------------------------------- -------- 87.4/111.0 MB 21.8 MB/s eta 0:00:02
#    ------------------------------- -------- 88.3/111.0 MB 21.8 MB/s eta 0:00:02
#    -------------------------------- ------- 89.4/111.0 MB 22.6 MB/s eta 0:00:01
#    -------------------------------- ------- 90.3/111.0 MB 22.6 MB/s eta 0:00:01
#    -------------------------------- ------- 91.2/111.0 MB 21.8 MB/s eta 0:00:01
#    --------------------------------- ------ 92.3/111.0 MB 22.6 MB/s eta 0:00:01
#    --------------------------------- ------ 93.4/111.0 MB 22.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 94.5/111.0 MB 22.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 95.4/111.0 MB 21.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 96.4/111.0 MB 22.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 97.4/111.0 MB 21.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 98.3/111.0 MB 21.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 99.3/111.0 MB 22.6 MB/s eta 0:00:01
#    ----------------------------------- --- 100.5/111.0 MB 22.6 MB/s eta 0:00:01
#    ----------------------------------- --- 101.6/111.0 MB 22.6 MB/s eta 0:00:01
#    ------------------------------------ -- 102.5/111.0 MB 22.5 MB/s eta 0:00:01
#    ------------------------------------ -- 103.5/111.0 MB 22.6 MB/s eta 0:00:01
#    ------------------------------------ -- 104.7/111.0 MB 22.6 MB/s eta 0:00:01
#    ------------------------------------- - 105.5/111.0 MB 21.8 MB/s eta 0:00:01
#    ------------------------------------- - 106.7/111.0 MB 22.6 MB/s eta 0:00:01
#    ------------------------------------- - 107.8/111.0 MB 23.4 MB/s eta 0:00:01
#    --------------------------------------  108.9/111.0 MB 23.4 MB/s eta 0:00:01
#    --------------------------------------  110.0/111.0 MB 23.4 MB/s eta 0:00:01
#    --------------------------------------  110.8/111.0 MB 23.4 MB/s eta 0:00:01
#    --------------------------------------  111.0/111.0 MB 22.5 MB/s eta 0:00:01
#    --------------------------------------  111.0/111.0 MB 22.5 MB/s eta 0:00:01
#    --------------------------------------  111.0/111.0 MB 22.5 MB/s eta 0:00:01
#    --------------------------------------  111.0/111.0 MB 22.5 MB/s eta 0:00:01
#    --------------------------------------- 111.0/111.0 MB 15.2 MB/s eta 0:00:00
# Using cached fsspec-2025.10.0-py3-none-any.whl (200 kB)
# Using cached huggingface_hub-0.36.0-py3-none-any.whl (566 kB)
# Using cached pyyaml-6.0.3-cp311-cp311-win_amd64.whl (158 kB)
# Downloading safetensors-0.7.0-cp38-abi3-win_amd64.whl (341 kB)
#    ---------------------------------------- 0.0/341.4 kB ? eta -:--:--
#    ---------------------------------------- 341.4/341.4 kB ? eta 0:00:00
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached tokenizers-0.22.1-cp39-abi3-win_amd64.whl (2.7 MB)
# Using cached filelock-3.20.0-py3-none-any.whl (16 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached markupsafe-3.0.3-cp311-cp311-win_amd64.whl (15 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: mpmath, sympy, safetensors, pyyaml, MarkupSafe, fsspec, filelock, jinja2, huggingface-hub, torch, tokenizers, transformers, accelerate
# Successfully installed MarkupSafe-3.0.3 accelerate-1.12.0 filelock-3.20.0 fsspec-2025.10.0 huggingface-hub-0.36.0 jinja2-3.1.6 mpmath-1.3.0 pyyaml-6.0.3 safetensors-0.7.0 sympy-1.14.0 tokenizers-0.22.1 torch-2.9.1 transformers-4.57.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install "accelerate>=0.27.2"
# Out:
# Requirement already satisfied: accelerate>=0.27.2 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (1.12.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from accelerate>=0.27.2) (2.3.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from accelerate>=0.27.2) (25.0)
# Requirement already satisfied: psutil in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from accelerate>=0.27.2) (7.1.3)
# Requirement already satisfied: pyyaml in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from accelerate>=0.27.2) (6.0.3)
# Requirement already satisfied: torch>=2.0.0 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from accelerate>=0.27.2) (2.9.1)
# Requirement already satisfied: huggingface_hub>=0.21.0 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from accelerate>=0.27.2) (0.36.0)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from accelerate>=0.27.2) (0.7.0)
# Requirement already satisfied: filelock in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from huggingface_hub>=0.21.0->accelerate>=0.27.2) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from huggingface_hub>=0.21.0->accelerate>=0.27.2) (2025.10.0)
# Requirement already satisfied: requests in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from huggingface_hub>=0.21.0->accelerate>=0.27.2) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from huggingface_hub>=0.21.0->accelerate>=0.27.2) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from huggingface_hub>=0.21.0->accelerate>=0.27.2) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from torch>=2.0.0->accelerate>=0.27.2) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from torch>=2.0.0->accelerate>=0.27.2) (3.5)
# Requirement already satisfied: jinja2 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from torch>=2.0.0->accelerate>=0.27.2) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate>=0.27.2) (1.3.0)
# Requirement already satisfied: colorama in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from tqdm>=4.42.1->huggingface_hub>=0.21.0->accelerate>=0.27.2) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from jinja2->torch>=2.0.0->accelerate>=0.27.2) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from requests->huggingface_hub>=0.21.0->accelerate>=0.27.2) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from requests->huggingface_hub>=0.21.0->accelerate>=0.27.2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from requests->huggingface_hub>=0.21.0->accelerate>=0.27.2) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from requests->huggingface_hub>=0.21.0->accelerate>=0.27.2) (2025.10.5)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install torch
# Out:
# Requirement already satisfied: torch in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (2.9.1)
# Requirement already satisfied: filelock in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from torch) (2025.10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from jinja2->torch) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import torch

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
import time
import pandas as pd
from typing import List, Dict

# %%
pip install torch torchvision --index-url https://download.pytorch.org/whl/cu126
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu126
# Requirement already satisfied: torch in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (2.9.1)
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/cu126/torchvision-0.24.1%2Bcu126-cp311-cp311-win_amd64.whl.metadata (6.1 kB)
# Requirement already satisfied: filelock in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from torch) (2025.10.0)
# Requirement already satisfied: numpy in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from torchvision) (2.3.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from torchvision) (12.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\anmrt\desktop\useful shit\nlp_labs\venv\lib\site-packages (from jinja2->torch) (3.0.3)
# Downloading https://download.pytorch.org/whl/cu126/torchvision-0.24.1%2Bcu126-cp311-cp311-win_amd64.whl (8.5 MB)
#    ---------------------------------------- 0.0/8.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.5 MB 1.9 MB/s eta 0:00:05
#     --------------------------------------- 0.1/8.5 MB 2.1 MB/s eta 0:00:04
#    - -------------------------------------- 0.3/8.5 MB 2.3 MB/s eta 0:00:04
#    -- ------------------------------------- 0.6/8.5 MB 3.5 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.1/8.5 MB 5.5 MB/s eta 0:00:02
#    --------- ------------------------------ 2.0/8.5 MB 7.9 MB/s eta 0:00:01
#    --------------- ------------------------ 3.4/8.5 MB 11.9 MB/s eta 0:00:01
#    ------------------ --------------------- 4.0/8.5 MB 12.7 MB/s eta 0:00:01
#    ------------------ --------------------- 4.0/8.5 MB 12.7 MB/s eta 0:00:01
#    --------------------- ------------------ 4.6/8.5 MB 10.8 MB/s eta 0:00:01
#    --------------------- ------------------ 4.6/8.5 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  8.5/8.5 MB 17.0 MB/s eta 0:00:01
#    ---------------------------------------- 8.5/8.5 MB 16.0 MB/s eta 0:00:00
# Installing collected packages: torchvision
# Successfully installed torchvision-0.24.1+cu126
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
torch.cuda.is_available()
# Out:
# False

# %%
# Загрузка модели и токенизатора
print("Загрузка модели Phi-3...")
model = AutoModelForCausalLM.from_pretrained(
    "microsoft/Phi-3-mini-4k-instruct",
    device_map="cuda",
    torch_dtype="auto",
    trust_remote_code=True,
)

tokenizer = AutoTokenizer.from_pretrained("microsoft/Phi-3-mini-4k-instruct")
print("Модель загружена успешно!")
# Out:
# Загрузка модели Phi-3...
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[18], line 3
#       1 # Загрузка модели и токенизатора
#       2 print("Загрузка модели Phi-3...")
# ----> 3 model = AutoModelForCausalLM.from_pretrained(
#       4     "microsoft/Phi-3-mini-4k-instruct",
#       5     device_map="cuda",
#       6     torch_dtype="auto",
#       7     trust_remote_code=True,
#       8 )
#      10 tokenizer = AutoTokenizer.from_pretrained("microsoft/Phi-3-mini-4k-instruct")
#      11 print("Модель загружена успешно!")
#
# File c:\Users\anmrt\Desktop\Useful shit\nlp_labs\venv\Lib\site-packages\transformers\models\auto\auto_factory.py:597, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     595         model_class.register_for_auto_class(auto_class=cls)
#     596     model_class = add_generation_mixin_to_remote_model(model_class)
# --> 597     return model_class.from_pretrained(
#     598         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     599     )
#     600 elif type(config) in cls._model_mapping:
#     601     model_class = _get_model_class(config, cls._model_mapping)
#
# File c:\Users\anmrt\Desktop\Useful shit\nlp_labs\venv\Lib\site-packages\transformers\modeling_utils.py:277, in restore_default_dtype.<locals>._wrapper(*args, **kwargs)
#     275 old_dtype = torch.get_default_dtype()
#     276 try:
# --> 277     return func(*args, **kwargs)
#     278 finally:
#     279     torch.set_default_dtype(old_dtype)
#
# File c:\Users\anmrt\Desktop\Useful shit\nlp_labs\venv\Lib\site-packages\transformers\modeling_utils.py:5048, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    5038     if dtype_orig is not None:
#    5039         torch.set_default_dtype(dtype_orig)
#    5041     (
#    5042         model,
#    5043         missing_keys,
#    5044         unexpected_keys,
#    5045         mismatched_keys,
#    5046         offload_index,
#    5047         error_msgs,
# -> 5048     ) = cls._load_pretrained_model(
#    5049         model,
#    5050         state_dict,
#    5051         checkpoint_files,
#    5052         pretrained_model_name_or_path,
#    5053         ignore_mismatched_sizes=ignore_mismatched_sizes,
#    5054         sharded_metadata=sharded_metadata,
#    5055         device_map=device_map,
#    5056         disk_offload_folder=offload_folder,
#    5057         dtype=dtype,
#    5058         hf_quantizer=hf_quantizer,
#    5059         keep_in_fp32_regex=keep_in_fp32_regex,
#    5060         device_mesh=device_mesh,
#    5061         key_mapping=key_mapping,
#    5062         weights_only=weights_only,
#    5063     )
#    5064 # make sure token embedding weights are still tied if needed
#    5065 model.tie_weights()
#
# File c:\Users\anmrt\Desktop\Useful shit\nlp_labs\venv\Lib\site-packages\transformers\modeling_utils.py:5432, in PreTrainedModel._load_pretrained_model(cls, model, state_dict, checkpoint_files, pretrained_model_name_or_path, ignore_mismatched_sizes, sharded_metadata, device_map, disk_offload_folder, dtype, hf_quantizer, keep_in_fp32_regex, device_mesh, key_mapping, weights_only)
#    5430 if device_map is not None and not is_hqq_or_quark:
#    5431     expanded_device_map = expand_device_map(device_map, expected_keys)
# -> 5432     caching_allocator_warmup(model, expanded_device_map, hf_quantizer)
#    5434 # Prepare and compatabilize arguments for serial and parallel shard loading
#    5435 args_list = [
#    5436     (
#    5437         shard_file,
#    (...)   5452     for shard_file in checkpoint_files
#    5453 ]
#
# File c:\Users\anmrt\Desktop\Useful shit\nlp_labs\venv\Lib\site-packages\transformers\modeling_utils.py:6089, in caching_allocator_warmup(model, expanded_device_map, hf_quantizer)
#    6087 if device.type in ["cuda", "xpu"]:
#    6088     torch_accelerator_module = getattr(torch, device.type)
# -> 6089     index = device.index if device.index is not None else torch_accelerator_module.current_device()
#    6090     device_memory = torch_accelerator_module.mem_get_info(index)[0]
#    6091     # Allow up to (max device memory - 1.2 GiB) in resource-constrained hardware configurations. Trying to reserve more
#    6092     # than that amount might sometimes lead to unnecessary cuda/xpu OOM, if the last parameter to be loaded on the device is large,
#    6093     # and the remaining reserved memory portion is smaller than the param size -> torch will then try to fully re-allocate all
#    (...)   6096     # Note that we use an absolute value instead of device proportion here, as a 8GiB device could still allocate too much
#    6097     # if using e.g. 90% of device size, while a 140GiB device would allocate too little
#
# File c:\Users\anmrt\Desktop\Useful shit\nlp_labs\venv\Lib\site-packages\torch\cuda\__init__.py:1069, in current_device()
#    1067 def current_device() -> int:
#    1068     r"""Return the index of a currently selected device."""
# -> 1069     _lazy_init()
#    1070     return torch._C._cuda_getDevice()
#
# File c:\Users\anmrt\Desktop\Useful shit\nlp_labs\venv\Lib\site-packages\torch\cuda\__init__.py:403, in _lazy_init()
#     398     raise RuntimeError(
#     399         "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     400         "multiprocessing, you must use the 'spawn' start method"
#     401     )
#     402 if not hasattr(torch._C, "_cuda_getDeviceCount"):
# --> 403     raise AssertionError("Torch not compiled with CUDA enabled")
#     404 if _cudart is None:
#     405     raise AssertionError(
#     406         "libcudart functions unavailable. It looks like you have a broken build?"
#     407     )
#
# AssertionError: Torch not compiled with CUDA enabled
